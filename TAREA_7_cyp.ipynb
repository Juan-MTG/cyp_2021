# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan-MTG/cyp_2021/blob/main/TAREA_7_cyp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#TAREA_7

print("INGRESE EL TOTAL DE PAISES DE SUR, CENTRO Y NORTE DE AMÉRICA: ")
TPS= int(input("PAISES DEL SUR: ")) #TOTAL DE PAISES DEL SUR
TPC= int(input("PAISES DEL CENTRO: "))#TOTAL DE PAISES DEL CENTRO
TPN= int(input("PAISES DEL NORTE: "))#TOTAL DE PAISES DEL NORTE
TPA= TPS + TPC + TPN #TOTAL DE PAISES DE AMÉRICA
if (1<=TPS<=30 and 1<=TPC<=30 and 1<=TPN<=30):
  print("\nINGRESE EL TOTAL DE PAISES DE SUDAMÉRICA: ")
  SUR= [0 for x in range(TPS)]
  for i in range(TPS):
    aux1 = input(f"NOMBRE DEL PAIS: ")
    SUR[i] = aux1

  print("\nINGRESE EL TOTAL DE PAISES DE CENTROAMÉRICA: ")
  CENTRO= [0 for x in range(TPC)]
  for i in range(TPC):
    aux2 = input(f"NOMBRE DEL PAIS: ")
    CENTRO[i] = aux2

  print("\nINGRESE EL TOTAL DE PAISES DE NORTEAMÉRICA: ")
  NORTE= [0 for x in range(TPN)]
  for i in range(TPN):
    aux3 = input(f"NOMBRE DEL PAIS: ")
    NORTE[i] = aux3
  
  #Variables de tipo entero. Se utilizan como índices de los arreglos
  #unidimensionales, su valor se incrementa a medida que se asignan valores a los arreglos.
  PS= 0
  PC= 0
  PN= 0
  PA= 0

  while (PS < TPS and PC < TPC and PN < TPN):
    
    if (SUR[PS] < CENTRO[PC] and SUR[PS] < NORTE[PN]):
      AMERICA[PA]= SUR[PS]
      PS =+1
    elif (CENTRO[PC] < NORTE[PN]):
      AMERICA[PA]= CENTRO[PC]
      PC =+1
    elif (NORTE [PN]< CENTRO [PC]):
      AMERICA[PA]= NORTE[PN]
      PN =+1
    PA +=1
    

  while (PS < TPS and PC < TPC):
    
    if (SUR[PS] < CENTRO[PC] ):
      AMERICA[PA] = SUR[PS]
      PS +=1
    else:
      AMERICA[PA] = CENTRO[PC]
      PC +=1
    PA +=1
    
  while (PS < TPS and PN < TPN):
    
    if (SUR[PS] < NORTE[PN] ):
      AMERICA[PA] = SUR[PS]
      PS +=1
    elif (NORTE[PN] < SUR[PS]):
      AMERICA[PA] = NORTE[PN]
      PN +=1
    PA +=1

  while (PC < TPC and PN < TPN):
    
    if (CENTRO[PC] < NORTE[PN]):
      AMERICA[PA] = CENTRO[PC]
      PC +=1
    elif (NORTE[PN] < CENTRO[PC]):
      AMERICA[PA] = NORTE[PN]
      PN +=1
    PA +=1
  print(AMERICA)
  while (PS < TPS):
    
    AMERICA[PA] = SUR[PS]
    PS +=1
    PA +=1

  while (PC < TPC):
    
    AMERICA[PA] = CENTRO[PC]
    PC +=1
    PA +=1
  
  while (PN < TPN):
    
    AMERICA[PA] = NORTE[PN]
    PN +=1
    PA +=1

  print("\nARREGLO AMÉRICA")
  
  for j in range(TPA):
    print(f"{AMERICA[j]}")




else:
  print("\nVERIFIQUE EL NÚMERO DE PAISES INGRESADOS")
# Out:
# INGRESE EL TOTAL DE PAISES DE SUR, CENTRO Y NORTE DE AMÉRICA:
# PAISES DEL SUR: 1
# PAISES DEL CENTRO: 1
# PAISES DEL NORTE: 1
#
# INGRESE EL TOTAL DE PAISES DE SUDAMÉRICA:
# NOMBRE DEL PAIS: BRASIL
#
# INGRESE EL TOTAL DE PAISES DE CENTROAMÉRICA:
# NOMBRE DEL PAIS: MEXICO
#
# INGRESE EL TOTAL DE PAISES DE NORTEAMÉRICA:
# NOMBRE DEL PAIS: ESTADOS UNIDOS
# ['BRASIL', 'ESTADOS UNIDOS', 'NICARAGUA']
#
# ARREGLO AMÉRICA
# BRASIL
# ESTADOS UNIDOS
# MEXICO

# %%
#TAREA_7

print("INGRESE EL TOTAL DE PAISES DE SUR, CENTRO Y NORTE DE AMÉRICA: ")
TPS= int(input("PAISES DEL SUR: ")) #TOTAL DE PAISES DEL SUR
TPC= int(input("PAISES DEL CENTRO: "))#TOTAL DE PAISES DEL CENTRO
TPN= int(input("PAISES DEL NORTE: "))#TOTAL DE PAISES DEL NORTE
TPA= TPS + TPC + TPN + 10 #TOTAL DE PAISES DE AMÉRICA
#SE AGREGÓ UN NÚMERO AL "TPA" PARA QUE NO HUBIERA PROBLEMAS CON EL RANGO

#Se declaran los arreglos
AMERICA= [0 for x in range(TPA)]
SUR= [0 for x in range(TPS)]
CENTRO= [0 for x in range(TPC)]
NORTE= [0 for x in range(TPN)]

#CONDICIONAL E INTRODUCCIÓN DE INFORMACIÓN
if (1<=TPS and TPS<=30 and 1<=TPC and TPC<=30 and 1<=TPN and TPN<=30):
  print("\nPAISES DE SUDAMÉRICA: ")
  for i in range(TPS):
    SUR[i] = input(f"NOMBRE DEL PAIS: ")
    
  print("\nPAISES DE CENTROAMÉRICA: ")
  for i in range(TPC):
    CENTRO[i] = input(f"NOMBRE DEL PAIS: ")
  
  print("\nPAISES DE NORTEAMÉRICA: ")
  for i in range(TPN):
    NORTE[i] = input(f"NOMBRE DEL PAIS: ")
  
  #Variables de tipo entero. Se utilizan como índices de los arreglos
  #unidimensionales, su valor se incrementa a medida que se asignan valores a los arreglos.
  PS= 0
  PC= 0
  PN= 0
  PA= 0
  while (PS != TPS and PC != TPC and PN != TPN):
    PA += 1
    if ((SUR[PS] < CENTRO[PC]) and (SUR[PS] < NORTE[PN])):
      AMERICA[PA]= SUR[PS]
      PS += 1
    elif (CENTRO[PC] < NORTE[PN]):
      AMERICA[PA]= CENTRO[PC]
      PC += 1
    else:
      AMERICA[PA]= NORTE[PN]
      PN += 1  

  while ((PS != TPS) and (PC != TPC)):
    PA += 1
    if (SUR[PS] < CENTRO[PC] ):
      AMERICA[PA] = SUR[PS]
      PS +=1
    else:
      AMERICA[PA] = CENTRO[PC]
      PC +=1
    
  while ((PS != TPS) and (PN != TPN)):
    PA += 1
    if (SUR[PS] < NORTE[PN]):
      AMERICA[PA] = SUR[PS]
      PS += 1
    else:
      AMERICA[PA] = NORTE[PN]
      PN +=1

  while ((PC != TPC) and (PN != TPN)):
    PA += 1
    if (CENTRO[PC] < NORTE[PN]):
      AMERICA[PA] = CENTRO[PC]
      PC += 1
    else :
      AMERICA[PA] = NORTE[PN]
      PN +=1
  
  while (PS != TPS):
    PA += 1
    AMERICA[PA] = SUR[PS]
    PS += 1

  while (PC != TPC):
    PA += 1
    AMERICA[PA] = CENTRO[PC]
    PC += 1
  
  while (PN != TPN):
    PA += 1
    AMERICA[PA] = NORTE[PN]
    PN += 1
    

  print("\nARREGLO AMÉRICA")
  
  for i in range(PA):
    print(f"{i + 1}.-- {AMERICA[i + 1]}")
    




else:
  print("\nVERIFIQUE EL NÚMERO DE PAISES INGRESADOS")
#FUENTE:
#http://lanic.utexas.edu/subject/countries/indexesp.html
# Out:
# INGRESE EL TOTAL DE PAISES DE SUR, CENTRO Y NORTE DE AMÉRICA:
# PAISES DEL SUR: 11
# PAISES DEL CENTRO: 7
# PAISES DEL NORTE: 3
#
# PAISES DE SUDAMÉRICA:
# NOMBRE DEL PAIS: ARGENTINA
# NOMBRE DEL PAIS: BOLIVIA
# NOMBRE DEL PAIS: BRASIL
# NOMBRE DEL PAIS: CHILE
# NOMBRE DEL PAIS: COLOMBIA
# NOMBRE DEL PAIS: ECUADOR
# NOMBRE DEL PAIS: GUYANA
# NOMBRE DEL PAIS: PARAGUAY
# NOMBRE DEL PAIS: PERÚ
# NOMBRE DEL PAIS: URUGUAY
# NOMBRE DEL PAIS: VENEZUELA
#
# PAISES DE CENTROAMÉRICA:
# NOMBRE DEL PAIS: BELICE
# NOMBRE DEL PAIS: COSTA RICA
# NOMBRE DEL PAIS: EL SALVADOR
# NOMBRE DEL PAIS: GUATEMALA
# NOMBRE DEL PAIS: HONDURAS
# NOMBRE DEL PAIS: NICARAGUA
# NOMBRE DEL PAIS: PANAMA
#
# PAISES DE NORTEAMÉRICA:
# NOMBRE DEL PAIS: CANADA
# NOMBRE DEL PAIS: ESTADOS UNIDOS
# NOMBRE DEL PAIS: MEXICO
#
# ARREGLO AMÉRICA
# 1.-- ARGENTINA
# 2.-- BELICE
# 3.-- BOLIVIA
# 4.-- BRASIL
# 5.-- CANADA
# 6.-- CHILE
# 7.-- COLOMBIA
# 8.-- COSTA RICA
# 9.-- ECUADOR
# 10.-- EL SALVADOR
# 11.-- ESTADOS UNIDOS
# ...
